# %%
import re
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Input, Dense, Dropout, LSTM, Bidirectional, Embedding
from sklearn.feature_extraction.text import CountVectorizer

# %%
def generar_diccionario(textos, sw, N):
    cv = CountVectorizer(stop_words = sw, max_features = N)
    cv.fit_transform(textos)
    diccionario = cv.vocabulary_
    diccionario = dict([(palabra, i+2) for i, palabra in enumerate(diccionario)])
    diccionario['DESC'] = 0
    diccionario['PAD'] = 1 
    return diccionario

def procesar_cadena(texto, diccionario, stop_words, T):
    # Identificar palabras en el texto
    palabras = re.findall(r'\b\w+\b', texto.lower())
    palabras = list(filter(lambda x: x not in stop_words, palabras))
    resultado = [] 
    for i in range(0, T):
        if i < len(palabras): 
            if palabras[i] in diccionario:
                resultado.append(diccionario[palabras[i]])
            else:
                resultado.append(diccionario['DESC'])
        else:
            resultado.append(diccionario['PAD'])
    return np.array(resultado)

# %%
path = "/kaggle/input/tripadvisor-reviews/tripadvisor_hotel_reviews.csv"

datos = pd.read_csv(path)

# Variable objetivo
y = datos.iloc[:, -1]
num_clases = len(y.unique())
# Codificamos con "one hot" las posibles categorías finales
y = pd.get_dummies(datos['Rating'], columns=['Rating'])

# Textos de reseñas
textos = datos['Review']
X = []
diccionario = generar_diccionario(textos, stop_words, N)
for texto in textos:
    X.append(procesar_cadena(texto, diccionario, stop_words, T))
# X contendrá las reseñas codificadas y rellenas con la misma longitud
X = np.array(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py:409: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['let', 'll', 're', 've', 'wouldn'] not in stop_words.
#   warnings.warn(

# %%
X
# Out:
# array([[    2,     3,     4, ...,     1,     1,     1],
#        [   77,    78,    79, ...,   131,   144,   130],
#        [    2,   229,    38, ...,   277,    22,   278],
#        ...,
#        [   77,    55,  1628, ...,     1,     1,     1],
#        [    3, 10487,  3935, ..., 15279,     0,     0],
#        [   51,    52,   684, ...,     1,     1,     1]])

# %%
X.shape
# Out:
# (20491, 100)

# %%
modelo = Sequential()
modelo.add(Input((X.shape[1], 1)))
modelo.add(LSTM(units=NEURONAS_CAPA, return_sequences=True))
modelo.add(Bidirectional(LSTM(units=NEURONAS_CAPA)))
modelo.add(Dense(units=num_clases, activation='softmax'))

modelo.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
modelo.fit(X, y, validation_split=0.2, epochs=EPOCHS, batch_size=128)
# Out:
# Epoch 1/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 29ms/step - accuracy: 0.4457 - loss: 1.3641 - val_accuracy: 0.5109 - val_loss: 1.2764
# Epoch 2/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.4700 - loss: 1.3162 - val_accuracy: 0.5213 - val_loss: 1.2432
# Epoch 3/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.4698 - loss: 1.3094 - val_accuracy: 0.5184 - val_loss: 1.2454
# Epoch 4/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.4696 - loss: 1.2979 - val_accuracy: 0.5174 - val_loss: 1.2261
# Epoch 5/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.4730 - loss: 1.3042 - val_accuracy: 0.5228 - val_loss: 1.2205
# Epoch 6/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.4774 - loss: 1.2830 - val_accuracy: 0.5279 - val_loss: 1.2267
# Epoch 7/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.4767 - loss: 1.2805 - val_accuracy: 0.5240 - val_loss: 1.2233
# Epoch 8/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.4853 - loss: 1.2619 - val_accuracy: 0.5257 - val_loss: 1.2094
# Epoch 9/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.4802 - loss: 1.2665 - val_accuracy: 0.5231 - val_loss: 1.2071
# Epoch 10/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.4890 - loss: 1.2556 - val_accuracy: 0.5250 - val_loss: 1.2019

# %%
import numpy as np
from keras.models import Model
from keras.layers import Input, Embedding

N = 5
D = 8

capa_entrada = Input(shape=(None,), dtype='int32')

embedding = Embedding(input_dim=N, output_dim=D)(capa_entrada)

modelo = Model(capa_entrada,embedding)
modelo.summary()

codificacion_entera = [4,1,3,3,3]
codificacion_embedding = modelo.predict(np.asarray([codificacion_entera]))

print()
print('Representación de {}'.format( str(codificacion_entera) ))
print(codificacion_embedding)
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, None)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding (Embedding)                │ (None, None, 8)             │              40 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 40 (160.00 B)
#  Trainable params: 40 (160.00 B)
#  Non-trainable params: 0 (0.00 B)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
#
# Representación de [4, 1, 3, 3, 3]
# [[[-0.01378427 -0.0389277   0.04386974 -0.0036249   0.02885877
#    -0.0436363   0.0236915  -0.02506156]
#   [-0.00625841  0.00869348  0.02515589  0.04868311 -0.04498123
#    -0.02511599  0.01106633 -0.00466142]
#   [-0.03504137 -0.00300815 -0.00655142  0.01696291 -0.01972781
#    -0.02173389  0.04273179  0.04724601]
#   [-0.03504137 -0.00300815 -0.00655142  0.01696291 -0.01972781
#    -0.02173389  0.04273179  0.04724601]
#   [-0.03504137 -0.00300815 -0.00655142  0.01696291 -0.01972781
#    -0.02173389  0.04273179  0.04724601]]]

# %%
N = 20000
T = 100
D = 128             # Dimensiones de los vectores de embedding
EPOCHS = 30
NEURONAS_CAPA = 128

# %%
modelo = Sequential()

# Añadimos 2 unidades más al tamaño para incluir los códigos de
# palabras desconocidas y de padding
modelo.add(Embedding(input_dim=N+2, output_dim=D))
modelo.add(Bidirectional(LSTM(units=NEURONAS_CAPA, return_sequences=True)))
modelo.add(Bidirectional(LSTM(units=NEURONAS_CAPA)))
modelo.add(Dense(units=num_clases, activation='softmax'))

modelo.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
modelo.fit(X, y, validation_split=0.2, epochs=EPOCHS, batch_size=128)
# Out:
# Epoch 1/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.4822 - loss: 1.2063 - val_accuracy: 0.6211 - val_loss: 0.8400
# Epoch 2/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - accuracy: 0.6684 - loss: 0.7668 - val_accuracy: 0.6445 - val_loss: 0.8519
# Epoch 3/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - accuracy: 0.7484 - loss: 0.5982 - val_accuracy: 0.6255 - val_loss: 0.8891
# Epoch 4/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.8141 - loss: 0.4720 - val_accuracy: 0.6072 - val_loss: 1.0565
# Epoch 5/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.8585 - loss: 0.3794 - val_accuracy: 0.6001 - val_loss: 1.1629
# Epoch 6/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.8924 - loss: 0.3030 - val_accuracy: 0.5931 - val_loss: 1.3458
# Epoch 7/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9225 - loss: 0.2281 - val_accuracy: 0.5748 - val_loss: 1.5455
# Epoch 8/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9422 - loss: 0.1728 - val_accuracy: 0.5828 - val_loss: 1.7885
# Epoch 9/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9637 - loss: 0.1184 - val_accuracy: 0.5933 - val_loss: 1.8485
# Epoch 10/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9475 - loss: 0.1479 - val_accuracy: 0.5914 - val_loss: 1.8774
# Epoch 11/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9728 - loss: 0.0862 - val_accuracy: 0.5797 - val_loss: 2.2022
# Epoch 12/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9672 - loss: 0.1015 - val_accuracy: 0.5889 - val_loss: 1.9370
# Epoch 13/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9835 - loss: 0.0575 - val_accuracy: 0.5701 - val_loss: 2.2626
# Epoch 14/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.9856 - loss: 0.0491 - val_accuracy: 0.5853 - val_loss: 2.3126
# Epoch 15/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.9868 - loss: 0.0469 - val_accuracy: 0.5721 - val_loss: 2.4910
# Epoch 16/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.9899 - loss: 0.0328 - val_accuracy: 0.5840 - val_loss: 2.4900
# Epoch 17/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - accuracy: 0.9867 - loss: 0.0429 - val_accuracy: 0.5748 - val_loss: 2.5076
# Epoch 18/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - accuracy: 0.9882 - loss: 0.0405 - val_accuracy: 0.5711 - val_loss: 2.7296
# Epoch 19/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - accuracy: 0.9921 - loss: 0.0281 - val_accuracy: 0.5831 - val_loss: 2.8092
# Epoch 20/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - accuracy: 0.9950 - loss: 0.0191 - val_accuracy: 0.5762 - val_loss: 2.6922
# Epoch 21/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - accuracy: 0.9668 - loss: 0.1042 - val_accuracy: 0.5767 - val_loss: 2.4422
# Epoch 22/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - accuracy: 0.9939 - loss: 0.0263 - val_accuracy: 0.5797 - val_loss: 2.6380
# Epoch 23/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - accuracy: 0.9954 - loss: 0.0163 - val_accuracy: 0.5779 - val_loss: 2.7688
# Epoch 24/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - accuracy: 0.9950 - loss: 0.0181 - val_accuracy: 0.5772 - val_loss: 2.9964
# Epoch 25/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.9967 - loss: 0.0135 - val_accuracy: 0.5755 - val_loss: 3.0027
# Epoch 26/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.9964 - loss: 0.0124 - val_accuracy: 0.5728 - val_loss: 3.1778
# Epoch 27/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.9947 - loss: 0.0174 - val_accuracy: 0.5809 - val_loss: 2.9848
# Epoch 28/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.9896 - loss: 0.0343 - val_accuracy: 0.5745 - val_loss: 3.0052
# Epoch 29/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.9938 - loss: 0.0210 - val_accuracy: 0.5753 - val_loss: 2.9930
# Epoch 30/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.9959 - loss: 0.0132 - val_accuracy: 0.5758 - val_loss: 3.1177

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Bidirectional, LSTM, Dense, Dropout
from tensorflow.keras.regularizers import l2

modelo = Sequential()

modelo.add(Embedding(input_dim=N+2, output_dim=D))
modelo.add(Bidirectional(LSTM(units=NEURONAS_CAPA//2, return_sequences=True)))
modelo.add(Dropout(0.5))
modelo.add(Bidirectional(LSTM(units=NEURONAS_CAPA//2)))
modelo.add(Dropout(0.4))
modelo.add(Dense(units=num_clases, activation='softmax', kernel_regularizer=l2(0.1)))

modelo.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

modelo.fit(X, y, validation_split=0.2, epochs=EPOCHS, batch_size=64)
# Out:
# Epoch 1/30
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.4634 - loss: 1.7731 - val_accuracy: 0.6192 - val_loss: 0.9506
# Epoch 2/30
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.6473 - loss: 0.8956 - val_accuracy: 0.6189 - val_loss: 0.9436
# Epoch 3/30
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.6958 - loss: 0.8211 - val_accuracy: 0.6202 - val_loss: 0.9358
# Epoch 4/30
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.7497 - loss: 0.7107 - val_accuracy: 0.6245 - val_loss: 1.0003
# Epoch 5/30
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.7904 - loss: 0.6371 - val_accuracy: 0.6145 - val_loss: 1.0196
# Epoch 6/30
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.8261 - loss: 0.5730 - val_accuracy: 0.5977 - val_loss: 1.0559
# Epoch 7/30
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.8381 - loss: 0.5509 - val_accuracy: 0.6021 - val_loss: 1.1340
# Epoch 8/30
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.8584 - loss: 0.5107 - val_accuracy: 0.6055 - val_loss: 1.1438
# Epoch 9/30
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.8819 - loss: 0.4569 - val_accuracy: 0.6121 - val_loss: 1.1580
# Epoch 10/30
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.8953 - loss: 0.4301 - val_accuracy: 0.6031 - val_loss: 1.2256
# Epoch 11/30
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9031 - loss: 0.4103 - val_accuracy: 0.5999 - val_loss: 1.2845
# Epoch 12/30
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9145 - loss: 0.3826 - val_accuracy: 0.5892 - val_loss: 1.2603
# Epoch 13/30
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.8967 - loss: 0.4315 - val_accuracy: 0.6055 - val_loss: 1.2952
# Epoch 14/30
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.9282 - loss: 0.3473 - val_accuracy: 0.5867 - val_loss: 1.3233
# Epoch 15/30
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9371 - loss: 0.3302 - val_accuracy: 0.5897 - val_loss: 1.3828
# Epoch 16/30
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9435 - loss: 0.3154 - val_accuracy: 0.5833 - val_loss: 1.2715
# Epoch 17/30
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9310 - loss: 0.3400 - val_accuracy: 0.5784 - val_loss: 1.3742
# Epoch 18/30
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.9435 - loss: 0.3106 - val_accuracy: 0.5833 - val_loss: 1.4640
# Epoch 19/30
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.9539 - loss: 0.2812 - val_accuracy: 0.5775 - val_loss: 1.4757
# Epoch 20/30
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9573 - loss: 0.2726 - val_accuracy: 0.5892 - val_loss: 1.3549
# Epoch 21/30
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9493 - loss: 0.2940 - val_accuracy: 0.5965 - val_loss: 1.3839
# Epoch 22/30
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.9547 - loss: 0.2793 - val_accuracy: 0.5875 - val_loss: 1.4379
# Epoch 23/30
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.9555 - loss: 0.2742 - val_accuracy: 0.5931 - val_loss: 1.3301
# Epoch 24/30
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.9531 - loss: 0.2849 - val_accuracy: 0.5821 - val_loss: 1.4675
# Epoch 25/30
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9649 - loss: 0.2490 - val_accuracy: 0.5899 - val_loss: 1.4872
# Epoch 26/30
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9622 - loss: 0.2560 - val_accuracy: 0.5626 - val_loss: 1.5103
# Epoch 27/30
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.9511 - loss: 0.2822 - val_accuracy: 0.5858 - val_loss: 1.4286
# Epoch 28/30
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.9638 - loss: 0.2489 - val_accuracy: 0.5792 - val_loss: 1.5210
# Epoch 29/30
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9687 - loss: 0.2332 - val_accuracy: 0.5594 - val_loss: 1.5296
# Epoch 30/30
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.9712 - loss: 0.2284 - val_accuracy: 0.5753 - val_loss: 1.5704

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Bidirectional, LSTM, Dense, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping

modelo = Sequential()

# Capa de embedding
modelo.add(Embedding(input_dim=N+2, output_dim=D))
modelo.add(Bidirectional(LSTM(units=NEURONAS_CAPA//3, return_sequences=True, dropout=0.4, recurrent_dropout=0.4)))
modelo.add(Bidirectional(LSTM(units=NEURONAS_CAPA//3, dropout=0.4, recurrent_dropout=0.4)))
modelo.add(Dense(units=num_clases, activation='softmax', kernel_regularizer=l2(0.1)))

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
modelo.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
modelo.fit(X, y, validation_split=0.2, epochs=EPOCHS, batch_size=128, callbacks=[early_stopping])
# Out:
# Epoch 1/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 71s 494ms/step - accuracy: 0.4239 - loss: 2.0681 - val_accuracy: 0.5980 - val_loss: 1.1863
# Epoch 2/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 62s 478ms/step - accuracy: 0.5865 - loss: 1.1539 - val_accuracy: 0.6053 - val_loss: 1.0105
# Epoch 3/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 60s 469ms/step - accuracy: 0.6234 - loss: 0.9852 - val_accuracy: 0.6138 - val_loss: 0.9832
# Epoch 4/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 65s 504ms/step - accuracy: 0.6526 - loss: 0.9036 - val_accuracy: 0.6236 - val_loss: 0.9532
# Epoch 5/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 65s 504ms/step - accuracy: 0.6876 - loss: 0.8455 - val_accuracy: 0.6145 - val_loss: 0.9738
# Epoch 6/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 64s 497ms/step - accuracy: 0.7043 - loss: 0.8274 - val_accuracy: 0.6106 - val_loss: 0.9904
# Epoch 7/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 65s 505ms/step - accuracy: 0.7285 - loss: 0.7823 - val_accuracy: 0.6121 - val_loss: 1.0089
# Epoch 8/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 64s 499ms/step - accuracy: 0.7431 - loss: 0.7594 - val_accuracy: 0.6131 - val_loss: 1.0138
# Epoch 9/30
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 65s 501ms/step - accuracy: 0.7550 - loss: 0.7350 - val_accuracy: 0.5994 - val_loss: 1.0449
